# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/JSON2YOLO
# Out:
# Cloning into 'JSON2YOLO'...
# remote: Enumerating objects: 262, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 262 (delta 92), reused 79 (delta 79), pack-reused 164
# Receiving objects: 100% (262/262), 69.61 KiB | 1.70 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
# Copy data from Drive to new directory in Colab
# !cp -R '/content/drive/MyDrive/uav_palm_data' '/content'

# %%
# !chmod g+w '/content/uav_palm_data/annotations/instances_train2017.json'

# %%
# !cp -f '/content/uav_palm_data/annotations/instances_train2017.json' '/content/uav_palm_data/train2017'
# Out:
# cp: cannot create regular file '/content/uav_palm_data/train2017/instances_train2017.json': Read-only file system

# %%
import sys
sys.path.append('/content/JSON2YOLO')
from labelbox_json2yolo import convert
from general_json2yolo import convert_coco_json

# %%
help(convert)
# Out:
# Help on function convert in module labelbox_json2yolo:
#
# convert(file, zip=True)

# %%
convert_coco_json('/content/drive/MyDrive/uav_palm_data/annotations/')
# Out:
# Annotations /content/drive/.shortcut-targets-by-id/17I8HVrGo812vpMdD2EKrkdw_61NVrUfb/uav_palm_data/annotations/instances_train2017.json: 100%|██████████| 262811/262811 [00:21<00:00, 12243.83it/s]
# Annotations /content/drive/.shortcut-targets-by-id/17I8HVrGo812vpMdD2EKrkdw_61NVrUfb/uav_palm_data/annotations/instances_val2017.json: 100%|██████████| 32846/32846 [00:02<00:00, 12111.90it/s]

# %%
import glob

f = '/content/instances_train2017/labels'
for f in glob.glob(f + '/*.txt'):
  print(f)
